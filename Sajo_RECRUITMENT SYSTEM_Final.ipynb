# %%
class recruitment:
    def __init__(self):
        print("--->SAJO RECRUITMENTS<---")
        self.dept={}
        self.dept['hre']=[]
        self.dept['hrf']=[]
        self.dept['ite']=[]
        self.dept['itf']=[]
        self.dept['fne']=[]
        self.dept['fnf']=[]
        self.dept['mge']=[]
        self.dept['mgf']=[]
        self.dept['tse']=[]
        self.dept['tsf']=[]
        
    def candidate(self):
        name=input('enter your name: ')
        age=int(input('enter your age: '))
        exp=int(input('Enter your experience: '))
        qualification=input('are you a graduate (select yes/no): ')
        specilisation=input('enter your specilisation (HR/IT/FN/MG/TS)')
        english_skills = input("Enter English skills level (Poor/Fair/Good/Excellent): ")
        position_specifics = input("Enter the position you are applying for (HR/IT/FN/MG/TS): ")
        if age<35:
            if specilisation.lower()==position_specifics.lower():
                D=position_specifics.lower()
                if exp>=1:
                    dp=D+'e'
                    self.dept[dp].append(name)
                    print("You are Eligible")
                else:
                    dp=D+'f'
                    self.dept[dp].append(name)
                    print("You are Eligible")
            else:
                print("You are not Eligible")
        else:
            print("You are not Eligible")
            
    def dept_rect(self):
        PW=int(input("Enter recruiter Password: "))
        if PW==1234:
            dept=input("Enter the dept you want to check (HR/IT/FN/MG/TS): ").lower()
            exp=input("Checking for experienced or fresh candidates (e/f)").lower()
            dp=dept+exp
            print("The recruits are:")
            print(self.dept[dp])
        else:
            print("Invalid Password")
r=recruitment()
while True:
    print("Enter your Category \n1 for Candidate \n2 for Recruiter")
    choice=int(input())
    if choice==1:
        r.candidate()
    elif choice==2:
        r.dept_rect()
    else:
        print("Invalid Input")
    
    while True:
        a=input("Do you want to continue (yes/no): ")
        if a.lower()=='yes':
            break
        elif a.lower()=='no':
            break
        else:
            print("Invalid Input")
            continue
    if a.lower()=='no':
        break
# Out:
# --->SAJO RECRUITMENTS<---
# Enter your Category
# 1 for Candidate
# 2 for Recruiter
# 1
# enter your name: sajo
# enter your age: 26
# Enter your experience: 2
# are you a graduate (select yes/no): yes
# enter your specilisation (HR/IT/FN/MG/TS)hr
# Enter English skills level (Poor/Fair/Good/Excellent): good
# Enter the position you are applying for (HR/IT/FN/MG/TS): hr
# You are Eligible
# Do you want to continue (yes/no): yes
# Enter your Category
# 1 for Candidate
# 2 for Recruiter
# 2
# Enter recruiter Password: 1234
# Enter the dept you want to check (HR/IT/FN/MG/TC): hr
# Checking for experienced or fresh candidates (e/f)e
# The recruits are:
# ['sajo']
# Do you want to continue (yes/no): no
